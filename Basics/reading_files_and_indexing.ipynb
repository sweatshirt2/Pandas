# %%
import pandas as pd # type: ignore

# %% [markdown]
# ### Reading CSV files

# %% [markdown]
# ##### Tips
# - Use r'' to read it as a string literal even with the backslashes
# - methods
#   - read_csv(...)
#   - read_table(..., sep=',' || delimiter=',')
# - kwargs
#   - header
#     - which row is the header and keep rows below it
#     - None creates indexes as an header and makes the old header a row of data
#   - names
#     - creating your own header

# %%
pd.read_csv(r'resources\countries of the world.csv', header = None, names = ['C', 'R'])
# Out:
#                    C                                    R
# 0            Country                               Region
# 1       Afghanistan         ASIA (EX. NEAR EAST)
# 2           Albania   EASTERN EUROPE
# 3           Algeria   NORTHERN AFRICA
# 4    American Samoa   OCEANIA
# ..               ...                                  ...
# 223       West Bank   NEAR EAST
# 224  Western Sahara   NORTHERN AFRICA
# 225           Yemen   NEAR EAST
# 226          Zambia   SUB-SAHARAN AFRICA
# 227        Zimbabwe   SUB-SAHARAN AFRICA
#
# [228 rows x 2 columns]

# %% [markdown]
# #### Reading Text Files

# %% [markdown]
# ##### Tips
# - methods
#   - read_csv(..., sep='\t' || delimiter='\t')
#   - read_table(...)
# - Kwrags

# %%
df1 = pd.read_csv(r'resources\countries of the world.txt', delimiter='\t')
pd.read_csv(r'resources\countries of the world.txt', sep='\t')
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %% [markdown]
# #### Reading JSON files

# %% [markdown]
# ##### Tips
# - methods
#   - read_json(...)

# %%
df2 = pd.read_json(r'resources\json_sample.json')
df2
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# 0  {'Genre': 'Drama', 'Gross': 'unknown', 'IMDB M...
#
#                    Film Stars Don'T Die In Liverpool  ...  \
# 0  {'popcornscore': 69, 'rating': 'R', 'tomatosco...  ...
#
#                                   The 15:17 To Paris  \
# 0  {'Genre': 'Drama', 'Gross': 'unknown', 'IMDB M...
#
#                                         The Commuter  \
# 0  {'popcornscore': 48, 'rating': 'PG13', 'tomato...
#
#                                  The Disaster Artist  \
# 0  {'popcornscore': 89, 'rating': 'R', 'tomatosco...
#
#                                 The Greatest Showman  \
# 0  {'Genre': 'Biography', 'Gross': '$627,248', 'I...
#
#                               The Insult (L'Insulte)  \
# 0  {'popcornscore': 86, 'rating': 'R', 'tomatosco...
#
#                                             The Post  \
# 0  {'Genre': 'Biography', 'Gross': '$463,228', 'I...
#
#                                   The Shape Of Water  \
# 0  {'Genre': 'Adventure', 'Gross': '$448,287', 'I...
#
#            Three Billboards Outside Ebbing, Missouri  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                            Till The End Of The World  \
# 0  {'popcornscore': -1, 'rating': 'NR', 'tomatosc...
#
#                                           Winchester
# 0  {'Genre': 'Biography', 'Gross': '$696,786', 'I...
#
# [1 rows x 38 columns]

# %% [markdown]
# #### Reading excel files

# %% [markdown]
# ##### Tips
# - methods
#   - read_excel(...)

# %%
pd.read_excel(r'resources\world_population_excel_workbook.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.read_excel(r'resources\world_population_excel_workbook.xlsx')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# #### Settings
# - Max Rows/Columns to show

# %%
pd.set_option('display.max.rows', 235)
pd.set_option('display.max.columns', 40)

# %% [markdown]
# #### Information about dataframes

# %%
df1.shape
# Out:
# (227, 2)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    object
#  1   Region   227 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df1.describe()
# Out:
#              Country                               Region
# count            227                                  227
# unique           227                                   11
# top     Afghanistan   SUB-SAHARAN AFRICA
# freq               1                                   51

# %% [markdown]
# #### Sneak peak at the dataframe
# - methods
#   - head(x)
#   - tail(x)
#     - x - number of rows, by default it's 5

# %%
df1.head(10)
# Out:
#               Country                               Region
# 0        Afghanistan         ASIA (EX. NEAR EAST)
# 1            Albania   EASTERN EUROPE
# 2            Algeria   NORTHERN AFRICA
# 3     American Samoa   OCEANIA
# 4            Andorra   WESTERN EUROPE
# 5             Angola   SUB-SAHARAN AFRICA
# 6           Anguilla               LATIN AMER. & CARIB
# 7  Antigua & Barbuda               LATIN AMER. & CARIB
# 8          Argentina               LATIN AMER. & CARIB
# 9            Armenia                  C.W. OF IND. STATES

# %%
df1.tail(10)
# Out:
#                 Country                               Region
# 217            Vanuatu   OCEANIA
# 218          Venezuela               LATIN AMER. & CARIB
# 219            Vietnam         ASIA (EX. NEAR EAST)
# 220     Virgin Islands               LATIN AMER. & CARIB
# 221  Wallis and Futuna   OCEANIA
# 222          West Bank   NEAR EAST
# 223     Western Sahara   NORTHERN AFRICA
# 224              Yemen   NEAR EAST
# 225             Zambia   SUB-SAHARAN AFRICA
# 226           Zimbabwe   SUB-SAHARAN AFRICA

# %%
pd.set_option('display.max.rows', 10)
pd.set_option('display.max.columns', 10)

# %% [markdown]
# ##### Reading specific columns
# - df[col_name]
# - df[[col_names]]

# %%
df1['Country']
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
df1[['Country', 'Region']]
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %% [markdown]
# ##### Reading specific rows
# - df.iloc[row_num] - using the row number no matter how indexed it is
# - df.loc[index_val] - using a value in the index column

# %%
df1.iloc[3]
# Out:
# Country                        American Samoa
# Region     OCEANIA
# Name: 3, dtype: object

# %%
df1.loc[3]
# Out:
# Country                        American Samoa
# Region     OCEANIA
# Name: 3, dtype: object

# %% [markdown]
# ### Indexing

# %% [markdown]
# ##### Setting Index Column

# %%
df = pd.read_csv(r'resources\world_population.csv', index_col='Rank')
df
# Out:
#      CCA3            Country           Capital Continent  2022 Population  \
# Rank
# 36    AFG        Afghanistan             Kabul      Asia       41128771.0
# 138   ALB            Albania            Tirana    Europe        2842321.0
# 34    DZA            Algeria           Algiers    Africa       44903225.0
# 213   ASM     American Samoa         Pago Pago   Oceania          44273.0
# 203   AND            Andorra  Andorra la Vella    Europe          79824.0
# ...   ...                ...               ...       ...              ...
# 226   WLF  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# 172   ESH     Western Sahara          El Aaiún    Africa         575986.0
# 46    YEM              Yemen             Sanaa      Asia       33696614.0
# 63    ZMB             Zambia            Lusaka    Africa       20017675.0
# 74    ZWE           Zimbabwe            Harare    Africa       16320537.0
#
#       ...  1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# Rank  ...
# 36    ...       10752971.0    652230.0            63.0587       1.0257
# 138   ...        2324731.0     28748.0            98.8702       0.9957
# 34    ...       13795915.0   2381741.0            18.8531       1.0164
# 213   ...          27075.0       199.0           222.4774       0.9831
# 203   ...          19860.0       468.0           170.5641       1.0100
# ...   ...              ...         ...                ...          ...
# 226   ...           9377.0       142.0            81.4930       0.9953
# 172   ...          76371.0    266000.0             2.1654       1.0184
# 46    ...        6843607.0    527968.0            63.8232       1.0217
# 63    ...        4281671.0    752612.0            26.5976       1.0280
# 74    ...        5202918.0    390757.0            41.7665       1.0204
#
#       World Population Percentage
# Rank
# 36                           0.52
# 138                          0.04
# 34                           0.56
# 213                          0.00
# 203                          0.00
# ...                           ...
# 226                          0.00
# 172                          0.01
# 46                           0.42
# 63                           0.25
# 74                           0.20
#
# [234 rows x 16 columns]

# %% [markdown]
# <i>Now to see the difference on loc and iloc...</i>

# %%
df.iloc[[1]]
# Out:
#      CCA3  Country Capital Continent  2022 Population  ...  1970 Population  \
# Rank                                                   ...
# 138   ALB  Albania  Tirana    Europe        2842321.0  ...        2324731.0
#
#       Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# Rank
# 138      28748.0            98.8702       0.9957                         0.04
#
# [1 rows x 16 columns]

# %%
df.loc[[1]]
# Out:
#      CCA3 Country  Capital Continent  2022 Population  ...  1970 Population  \
# Rank                                                   ...
# 1     CHN   China  Beijing      Asia     1.425887e+09  ...      822534450.0
#
#       Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# Rank
# 1      9706961.0           146.8933          1.0                        17.88
#
# [1 rows x 16 columns]

# %% [markdown]
# ##### <i>Note</i>
# - when setting another column as an index column DO NOT forget to reset the index if the current index column must be kept as just another column to store data
# - the inplace kwarg is false by default, if true it changes the current df instead of returning a new one

# %%
df.reset_index(inplace=True)
df
# Out:
#      Rank CCA3            Country           Capital Continent  ...  \
# 0      36  AFG        Afghanistan             Kabul      Asia  ...
# 1     138  ALB            Albania            Tirana    Europe  ...
# 2      34  DZA            Algeria           Algiers    Africa  ...
# 3     213  ASM     American Samoa         Pago Pago   Oceania  ...
# 4     203  AND            Andorra  Andorra la Vella    Europe  ...
# ..    ...  ...                ...               ...       ...  ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania  ...
# 230   172  ESH     Western Sahara          El Aaiún    Africa  ...
# 231    46  YEM              Yemen             Sanaa      Asia  ...
# 232    63  ZMB             Zambia            Lusaka    Africa  ...
# 233    74  ZWE           Zimbabwe            Harare    Africa  ...
#
#      1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 0         10752971.0    652230.0            63.0587       1.0257
# 1          2324731.0     28748.0            98.8702       0.9957
# 2         13795915.0   2381741.0            18.8531       1.0164
# 3            27075.0       199.0           222.4774       0.9831
# 4            19860.0       468.0           170.5641       1.0100
# ..               ...         ...                ...          ...
# 229           9377.0       142.0            81.4930       0.9953
# 230          76371.0    266000.0             2.1654       1.0184
# 231        6843607.0    527968.0            63.8232       1.0217
# 232        4281671.0    752612.0            26.5976       1.0280
# 233        5202918.0    390757.0            41.7665       1.0204
#
#      World Population Percentage
# 0                           0.52
# 1                           0.04
# 2                           0.56
# 3                           0.00
# 4                           0.00
# ..                           ...
# 229                         0.00
# 230                         0.01
# 231                         0.42
# 232                         0.25
# 233                         0.20
#
# [234 rows x 17 columns]

# %% [markdown]
# ##### <i>Note</i>
# - set_index method sets a new index column just as index_col attribute we used when we read the file

# %%
df.set_index('Country', inplace=True)
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
#                    ...  1970 Population  Area (km²)  Density (per km²)  \
# Country            ...
# Afghanistan        ...       10752971.0    652230.0            63.0587
# Albania            ...        2324731.0     28748.0            98.8702
# Algeria            ...       13795915.0   2381741.0            18.8531
# American Samoa     ...          27075.0       199.0           222.4774
# Andorra            ...          19860.0       468.0           170.5641
# ...                ...              ...         ...                ...
# Wallis and Futuna  ...           9377.0       142.0            81.4930
# Western Sahara     ...          76371.0    266000.0             2.1654
# Yemen              ...        6843607.0    527968.0            63.8232
# Zambia             ...        4281671.0    752612.0            26.5976
# Zimbabwe           ...        5202918.0    390757.0            41.7665
#
#                    Growth Rate  World Population Percentage
# Country
# Afghanistan             1.0257                         0.52
# Albania                 0.9957                         0.04
# Algeria                 1.0164                         0.56
# American Samoa          0.9831                         0.00
# Andorra                 1.0100                         0.00
# ...                        ...                          ...
# Wallis and Futuna       0.9953                         0.00
# Western Sahara          1.0184                         0.01
# Yemen                   1.0217                         0.42
# Zambia                  1.0280                         0.25
# Zimbabwe                1.0204                         0.20
#
# [234 rows x 16 columns]

# %%
df.loc[['Andorra']]
# Out:
#          Rank CCA3           Capital Continent  2022 Population  ...  \
# Country                                                          ...
# Andorra   203  AND  Andorra la Vella    Europe          79824.0  ...
#
#          1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# Country
# Andorra          19860.0       468.0           170.5641         1.01
#
#          World Population Percentage
# Country
# Andorra                          0.0
#
# [1 rows x 16 columns]

# %% [markdown]
# ##### <i>Almost forgot resetting the index 😅</i>

# %%
df.reset_index(inplace=True)

# %%
df.set_index('Continent', inplace=True)
df
# Out:
#            Rank CCA3            Country           Capital  2022 Population  \
# Continent
# Asia         36  AFG        Afghanistan             Kabul       41128771.0
# Europe      138  ALB            Albania            Tirana        2842321.0
# Africa       34  DZA            Algeria           Algiers       44903225.0
# Oceania     213  ASM     American Samoa         Pago Pago          44273.0
# Europe      203  AND            Andorra  Andorra la Vella          79824.0
# ...         ...  ...                ...               ...              ...
# Oceania     226  WLF  Wallis and Futuna          Mata-Utu          11572.0
# Africa      172  ESH     Western Sahara          El Aaiún         575986.0
# Asia         46  YEM              Yemen             Sanaa       33696614.0
# Africa       63  ZMB             Zambia            Lusaka       20017675.0
# Africa       74  ZWE           Zimbabwe            Harare       16320537.0
#
#            2020 Population  2015 Population  2010 Population  2000 Population  \
# Continent
# Asia            38972230.0       33753499.0       28189672.0       19542982.0
# Europe           2866849.0        2882481.0        2913399.0        3182021.0
# Africa          43451666.0       39543154.0       35856344.0       30774621.0
# Oceania            46189.0          51368.0          54849.0          58230.0
# Europe             77700.0          71746.0          71519.0          66097.0
# ...                    ...              ...              ...              ...
# Oceania            11655.0          12182.0          13142.0          14723.0
# Africa            556048.0         491824.0         413296.0         270375.0
# Asia            32284046.0       28516545.0       24743946.0       18628700.0
# Africa          18927715.0              NaN       13792086.0        9891136.0
# Africa          15669666.0       14154937.0       12839771.0       11834676.0
#
#            1990 Population  1980 Population  1970 Population  Area (km²)  \
# Continent
# Asia            10694796.0       12486631.0       10752971.0    652230.0
# Europe           3295066.0        2941651.0        2324731.0     28748.0
# Africa          25518074.0       18739378.0       13795915.0   2381741.0
# Oceania            47818.0          32886.0          27075.0       199.0
# Europe             53569.0          35611.0          19860.0       468.0
# ...                    ...              ...              ...         ...
# Oceania            13454.0          11315.0           9377.0       142.0
# Africa            178529.0         116775.0          76371.0    266000.0
# Asia            13375121.0        9204938.0        6843607.0    527968.0
# Africa           7686401.0        5720438.0        4281671.0    752612.0
# Africa          10113893.0        7049926.0        5202918.0    390757.0
#
#            Density (per km²)  Growth Rate  World Population Percentage
# Continent
# Asia                 63.0587       1.0257                         0.52
# Europe               98.8702       0.9957                         0.04
# Africa               18.8531       1.0164                         0.56
# Oceania             222.4774       0.9831                         0.00
# Europe              170.5641       1.0100                         0.00
# ...                      ...          ...                          ...
# Oceania              81.4930       0.9953                         0.00
# Africa                2.1654       1.0184                         0.01
# Asia                 63.8232       1.0217                         0.42
# Africa               26.5976       1.0280                         0.25
# Africa               41.7665       1.0204                         0.20
#
# [234 rows x 16 columns]

# %% [markdown]
# ##### <i>Note</i>
# - Unlike iloc return multiple rows using loc is possible

# %%
df.loc[['Europe']].head()
# Out:
#            Country  Rank CCA3           Capital  2022 Population  ...  \
# Continent                                                         ...
# Europe     Albania   138  ALB            Tirana        2842321.0  ...
# Europe     Andorra   203  AND  Andorra la Vella          79824.0  ...
# Europe     Austria    99  AUT            Vienna        8939617.0  ...
# Europe     Belarus    96  BLR             Minsk        9534954.0  ...
# Europe     Belgium    81  BEL          Brussels       11655930.0  ...
#
#            1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# Continent
# Europe           2324731.0     28748.0            98.8702       0.9957
# Europe             19860.0       468.0           170.5641       1.0100
# Europe           7465301.0     83871.0           106.5877       1.0020
# Europe           9170786.0    207600.0            45.9295       0.9955
# Europe           9629376.0     30528.0           381.8111       1.0038
#
#            World Population Percentage
# Continent
# Europe                            0.04
# Europe                            0.00
# Europe                            0.11
# Europe                            0.12
# Europe                            0.15
#
# [5 rows x 16 columns]

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ##### <i>Note</i>
# - multiple columns can be set as indexes
# - an index column cannot be selected using df[column_name]

# %%
df.set_index(['Continent', 'Country'], inplace=True)
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
#                              2020 Population  ...  1970 Population  \
# Continent Country                             ...
# Asia      Afghanistan             38972230.0  ...       10752971.0
# Europe    Albania                  2866849.0  ...        2324731.0
# Africa    Algeria                 43451666.0  ...       13795915.0
# Oceania   American Samoa             46189.0  ...          27075.0
# Europe    Andorra                    77700.0  ...          19860.0
# ...                                      ...  ...              ...
# Oceania   Wallis and Futuna          11655.0  ...           9377.0
# Africa    Western Sahara            556048.0  ...          76371.0
# Asia      Yemen                   32284046.0  ...        6843607.0
# Africa    Zambia                  18927715.0  ...        4281671.0
#           Zimbabwe                15669666.0  ...        5202918.0
#
#                              Area (km²)  Density (per km²)  Growth Rate  \
# Continent Country
# Asia      Afghanistan          652230.0            63.0587       1.0257
# Europe    Albania               28748.0            98.8702       0.9957
# Africa    Algeria             2381741.0            18.8531       1.0164
# Oceania   American Samoa          199.0           222.4774       0.9831
# Europe    Andorra                 468.0           170.5641       1.0100
# ...                                 ...                ...          ...
# Oceania   Wallis and Futuna       142.0            81.4930       0.9953
# Africa    Western Sahara       266000.0             2.1654       1.0184
# Asia      Yemen                527968.0            63.8232       1.0217
# Africa    Zambia               752612.0            26.5976       1.0280
#           Zimbabwe             390757.0            41.7665       1.0204
#
#                              World Population Percentage
# Continent Country
# Asia      Afghanistan                               0.52
# Europe    Albania                                   0.04
# Africa    Algeria                                   0.56
# Oceania   American Samoa                            0.00
# Europe    Andorra                                   0.00
# ...                                                  ...
# Oceania   Wallis and Futuna                         0.00
# Africa    Western Sahara                            0.01
# Asia      Yemen                                     0.42
# Africa    Zambia                                    0.25
#           Zimbabwe                                  0.20
#
# [234 rows x 15 columns]

# %% [markdown]
# ##### Sorting using the index column
# - kwargs
#   - ascending
#     - takes a boolean value (pretty much self explantory)

# %%
df.sort_index()
df.sort_index(ascending=False)
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# South America Venezuela       51  VEN      Caracas       28301696.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Peru            44  PER         Lima       34049588.0
#               Paraguay       109  PRY     Asunción        6780744.0
# ...                          ...  ...          ...              ...
# Africa        Burkina Faso    58  BFA  Ouagadougou       22673762.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Angola          42  AGO       Luanda       35588987.0
#               Algeria         34  DZA      Algiers       44903225.0
#
#                             2020 Population  ...  1970 Population  Area (km²)  \
# Continent     Country                        ...
# South America Venezuela          28490453.0  ...       11355475.0         NaN
#               Uruguay             3429086.0  ...        2790265.0    181034.0
#               Suriname             607065.0  ...         379918.0    163820.0
#               Peru               33304756.0  ...       13562371.0   1285216.0
#               Paraguay            6618695.0  ...        2408787.0    406752.0
# ...                                     ...  ...              ...         ...
# Africa        Burkina Faso       21522626.0  ...        5611666.0    272967.0
#               Botswana            2546402.0  ...         592244.0    582000.0
#               Benin              12643123.0  ...        3023443.0    112622.0
#               Angola             33428485.0  ...        6029700.0   1246700.0
#               Algeria            43451666.0  ...       13795915.0   2381741.0
#
#                             Density (per km²)  Growth Rate  \
# Continent     Country
# South America Venezuela               30.8820       1.0036
#               Uruguay                 18.9069       0.9990
#               Suriname                 3.7727       1.0082
#               Peru                    26.4933       1.0099
#               Paraguay                16.6705       1.0115
# ...                                       ...          ...
# Africa        Burkina Faso            83.0641       1.0259
#               Botswana                 4.5194       1.0162
#               Benin                  118.5635       1.0274
#               Angola                  28.5466       1.0315
#               Algeria                 18.8531       1.0164
#
#                             World Population Percentage
# Continent     Country
# South America Venezuela                            0.35
#               Uruguay                              0.04
#               Suriname                             0.01
#               Peru                                 0.43
#               Paraguay                             0.09
# ...                                                 ...
# Africa        Burkina Faso                         0.28
#               Botswana                             0.03
#               Benin                                0.17
#               Angola                               0.45
#               Algeria                              0.56
#
# [234 rows x 15 columns]

# %%
df.sort_index(ascending=[True, False])
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Continent     Country
# Africa        Zimbabwe          74  ZWE        Harare       16320537.0
#               Zambia            63  ZMB        Lusaka       20017675.0
#               Western Sahara   172  ESH      El Aaiún         575986.0
#               Uganda            31  UGA       Kampala       47249585.0
#               Tunisia           79  TUN         Tunis       12356117.0
# ...                            ...  ...           ...              ...
# South America Colombia          28  COL        Bogota       51874024.0
#               Chile             65  CHL      Santiago       19603733.0
#               Brazil             7  BRA      Brasilia      215313498.0
#               Bolivia           80  BOL         Sucre       12224110.0
#               Argentina         33  ARG  Buenos Aires       45510318.0
#
#                               2020 Population  ...  1970 Population  \
# Continent     Country                          ...
# Africa        Zimbabwe             15669666.0  ...        5202918.0
#               Zambia               18927715.0  ...        4281671.0
#               Western Sahara         556048.0  ...          76371.0
#               Uganda               44404611.0  ...       10317212.0
#               Tunisia              12161723.0  ...        5047404.0
# ...                                       ...  ...              ...
# South America Colombia             50930662.0  ...       20905254.0
#               Chile                19300315.0  ...        9820481.0
#               Brazil              213196304.0  ...       96369875.0
#               Bolivia              11936162.0  ...        4585693.0
#               Argentina            45036032.0  ...       23842803.0
#
#                               Area (km²)  Density (per km²)  Growth Rate  \
# Continent     Country
# Africa        Zimbabwe          390757.0            41.7665       1.0204
#               Zambia            752612.0            26.5976       1.0280
#               Western Sahara    266000.0             2.1654       1.0184
#               Uganda            241550.0           195.6100       1.0304
#               Tunisia           163610.0            75.5218       1.0076
# ...                                  ...                ...          ...
# South America Colombia         1141748.0            45.4339       1.0069
#               Chile             756102.0            25.9274       1.0057
#               Brazil           8515767.0            25.2841       1.0046
#               Bolivia          1098581.0            11.1272       1.0120
#               Argentina        2780400.0            16.3683       1.0052
#
#                               World Population Percentage
# Continent     Country
# Africa        Zimbabwe                               0.20
#               Zambia                                 0.25
#               Western Sahara                         0.01
#               Uganda                                 0.59
#               Tunisia                                0.15
# ...                                                   ...
# South America Colombia                               0.65
#               Chile                                  0.25
#               Brazil                                 2.70
#               Bolivia                                0.15
#               Argentina                              0.57
#
# [234 rows x 15 columns]

# %% [markdown]
# ##### Renaming Columns

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Continent            Country  Rank CCA3           Capital  ...  \
# 0        Asia        Afghanistan    36  AFG             Kabul  ...
# 1      Europe            Albania   138  ALB            Tirana  ...
# 2      Africa            Algeria    34  DZA           Algiers  ...
# 3     Oceania     American Samoa   213  ASM         Pago Pago  ...
# 4      Europe            Andorra   203  AND  Andorra la Vella  ...
# ..        ...                ...   ...  ...               ...  ...
# 229   Oceania  Wallis and Futuna   226  WLF          Mata-Utu  ...
# 230    Africa     Western Sahara   172  ESH          El Aaiún  ...
# 231      Asia              Yemen    46  YEM             Sanaa  ...
# 232    Africa             Zambia    63  ZMB            Lusaka  ...
# 233    Africa           Zimbabwe    74  ZWE            Harare  ...
#
#      1970 Population  Area (km²)  Density (per km²)  Growth Rate  \
# 0         10752971.0    652230.0            63.0587       1.0257
# 1          2324731.0     28748.0            98.8702       0.9957
# 2         13795915.0   2381741.0            18.8531       1.0164
# 3            27075.0       199.0           222.4774       0.9831
# 4            19860.0       468.0           170.5641       1.0100
# ..               ...         ...                ...          ...
# 229           9377.0       142.0            81.4930       0.9953
# 230          76371.0    266000.0             2.1654       1.0184
# 231        6843607.0    527968.0            63.8232       1.0217
# 232        4281671.0    752612.0            26.5976       1.0280
# 233        5202918.0    390757.0            41.7665       1.0204
#
#      World Population Percentage
# 0                           0.52
# 1                           0.04
# 2                           0.56
# 3                           0.00
# 4                           0.00
# ..                           ...
# 229                         0.00
# 230                         0.01
# 231                         0.42
# 232                         0.25
# 233                         0.20
#
# [234 rows x 17 columns]

# %%
df.rename(columns={'Country': 'Name'})
# Out:
#            Rank CCA3               Name           Capital  2022 Population  \
# Continent
# Asia         36  AFG        Afghanistan             Kabul       41128771.0
# Europe      138  ALB            Albania            Tirana        2842321.0
# Africa       34  DZA            Algeria           Algiers       44903225.0
# Oceania     213  ASM     American Samoa         Pago Pago          44273.0
# Europe      203  AND            Andorra  Andorra la Vella          79824.0
# ...         ...  ...                ...               ...              ...
# Oceania     226  WLF  Wallis and Futuna          Mata-Utu          11572.0
# Africa      172  ESH     Western Sahara          El Aaiún         575986.0
# Asia         46  YEM              Yemen             Sanaa       33696614.0
# Africa       63  ZMB             Zambia            Lusaka       20017675.0
# Africa       74  ZWE           Zimbabwe            Harare       16320537.0
#
#            2020 Population  2015 Population  2010 Population  2000 Population  \
# Continent
# Asia            38972230.0       33753499.0       28189672.0       19542982.0
# Europe           2866849.0        2882481.0        2913399.0        3182021.0
# Africa          43451666.0       39543154.0       35856344.0       30774621.0
# Oceania            46189.0          51368.0          54849.0          58230.0
# Europe             77700.0          71746.0          71519.0          66097.0
# ...                    ...              ...              ...              ...
# Oceania            11655.0          12182.0          13142.0          14723.0
# Africa            556048.0         491824.0         413296.0         270375.0
# Asia            32284046.0       28516545.0       24743946.0       18628700.0
# Africa          18927715.0              NaN       13792086.0        9891136.0
# Africa          15669666.0       14154937.0       12839771.0       11834676.0
#
#            1990 Population  1980 Population  1970 Population  Area (km²)  \
# Continent
# Asia            10694796.0       12486631.0       10752971.0    652230.0
# Europe           3295066.0        2941651.0        2324731.0     28748.0
# Africa          25518074.0       18739378.0       13795915.0   2381741.0
# Oceania            47818.0          32886.0          27075.0       199.0
# Europe             53569.0          35611.0          19860.0       468.0
# ...                    ...              ...              ...         ...
# Oceania            13454.0          11315.0           9377.0       142.0
# Africa            178529.0         116775.0          76371.0    266000.0
# Asia            13375121.0        9204938.0        6843607.0    527968.0
# Africa           7686401.0        5720438.0        4281671.0    752612.0
# Africa          10113893.0        7049926.0        5202918.0    390757.0
#
#            Density (per km²)  Growth Rate  World Population Percentage
# Continent
# Asia                 63.0587       1.0257                         0.52
# Europe               98.8702       0.9957                         0.04
# Africa               18.8531       1.0164                         0.56
# Oceania             222.4774       0.9831                         0.00
# Europe              170.5641       1.0100                         0.00
# ...                      ...          ...                          ...
# Oceania              81.4930       0.9953                         0.00
# Africa                2.1654       1.0184                         0.01
# Asia                 63.8232       1.0217                         0.42
# Africa               26.5976       1.0280                         0.25
# Africa               41.7665       1.0204                         0.20
#
# [234 rows x 16 columns]

# %% [markdown]
# ##### <i>Note</i>
# - iloc have issues with multiple indexed then sorted dataframes, by reading the old indexed column

# %%
df.iloc[[0]]
# Out:
#                        Rank CCA3 Capital  2022 Population  2020 Population  \
# Continent Country
# Asia      Afghanistan    36  AFG   Kabul       41128771.0       38972230.0
#
#                        2015 Population  2010 Population  2000 Population  \
# Continent Country
# Asia      Afghanistan       33753499.0       28189672.0       19542982.0
#
#                        1990 Population  1980 Population  1970 Population  \
# Continent Country
# Asia      Afghanistan       10694796.0       12486631.0       10752971.0
#
#                        Area (km²)  Density (per km²)  Growth Rate  \
# Continent Country
# Asia      Afghanistan    652230.0            63.0587       1.0257
#
#                        World Population Percentage
# Continent Country
# Asia      Afghanistan                         0.52

# %% [markdown]
# ##### Picking multiple rows and columns

# %%
df = pd.read_csv(r'resources\world_population.csv')
df.iloc[2:8]
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 2       44903225.0       43451666.0       39543154.0       35856344.0
# 3          44273.0          46189.0          51368.0          54849.0
# 4          79824.0          77700.0          71746.0          71519.0
# 5       35588987.0       33428485.0       28127721.0       23364185.0
# 6          15857.0          15585.0          14525.0          13172.0
# 7          93763.0          92664.0          89941.0          85695.0
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# 2       30774621.0       25518074.0       18739378.0       13795915.0
# 3          58230.0          47818.0          32886.0          27075.0
# 4          66097.0          53569.0          35611.0          19860.0
# 5       16394062.0       11828638.0        8330047.0        6029700.0
# 6          11047.0           8316.0           6560.0           6283.0
# 7          75055.0          63328.0          64888.0          64516.0
#
#    Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 2   2381741.0            18.8531       1.0164                         0.56
# 3       199.0           222.4774       0.9831                         0.00
# 4       468.0           170.5641       1.0100                         0.00
# 5   1246700.0            28.5466       1.0315                         0.45
# 6        91.0           174.2527       1.0066                         0.00
# 7       442.0           212.1335       1.0058                         0.00

# %%
df[['Country', 'Capital', 'Growth Rate']]
# Out:
#                Country           Capital  Growth Rate
# 0          Afghanistan             Kabul       1.0257
# 1              Albania            Tirana       0.9957
# 2              Algeria           Algiers       1.0164
# 3       American Samoa         Pago Pago       0.9831
# 4              Andorra  Andorra la Vella       1.0100
# ..                 ...               ...          ...
# 229  Wallis and Futuna          Mata-Utu       0.9953
# 230     Western Sahara          El Aaiún       1.0184
# 231              Yemen             Sanaa       1.0217
# 232             Zambia            Lusaka       1.0280
# 233           Zimbabwe            Harare       1.0204
#
# [234 rows x 3 columns]

# %% [markdown]
# ##### Merging both approaches

# %%
df[['Country', 'Capital', 'Growth Rate']].iloc[2:8]
# Out:
#                Country           Capital  Growth Rate
# 2              Algeria           Algiers       1.0164
# 3       American Samoa         Pago Pago       0.9831
# 4              Andorra  Andorra la Vella       1.0100
# 5               Angola            Luanda       1.0315
# 6             Anguilla        The Valley       1.0066
# 7  Antigua and Barbuda      Saint John’s       1.0058

# %% [markdown]
# ##### <i>To test iloc</i>

# %%
df = pd.read_csv(r'resources\world_population.csv')
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# 2         44903225.0       43451666.0       39543154.0       35856344.0
# 3            44273.0          46189.0          51368.0          54849.0
# 4            79824.0          77700.0          71746.0          71519.0
# ..               ...              ...              ...              ...
# 229          11572.0          11655.0          12182.0          13142.0
# 230         575986.0         556048.0         491824.0         413296.0
# 231       33696614.0       32284046.0       28516545.0       24743946.0
# 232       20017675.0       18927715.0              NaN       13792086.0
# 233       16320537.0       15669666.0       14154937.0       12839771.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 0         19542982.0       10694796.0       12486631.0       10752971.0
# 1          3182021.0        3295066.0        2941651.0        2324731.0
# 2         30774621.0       25518074.0       18739378.0       13795915.0
# 3            58230.0          47818.0          32886.0          27075.0
# 4            66097.0          53569.0          35611.0          19860.0
# ..               ...              ...              ...              ...
# 229          14723.0          13454.0          11315.0           9377.0
# 230         270375.0         178529.0         116775.0          76371.0
# 231       18628700.0       13375121.0        9204938.0        6843607.0
# 232        9891136.0        7686401.0        5720438.0        4281671.0
# 233       11834676.0       10113893.0        7049926.0        5202918.0
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0      652230.0            63.0587       1.0257                         0.52
# 1       28748.0            98.8702       0.9957                         0.04
# 2     2381741.0            18.8531       1.0164                         0.56
# 3         199.0           222.4774       0.9831                         0.00
# 4         468.0           170.5641       1.0100                         0.00
# ..          ...                ...          ...                          ...
# 229       142.0            81.4930       0.9953                         0.00
# 230    266000.0             2.1654       1.0184                         0.01
# 231    527968.0            63.8232       1.0217                         0.42
# 232    752612.0            26.5976       1.0280                         0.25
# 233    390757.0            41.7665       1.0204                         0.20
#
# [234 rows x 17 columns]

# %%
df.iloc[[0]]
# Out:
#    Rank CCA3      Country Capital Continent  2022 Population  2020 Population  \
# 0    36  AFG  Afghanistan   Kabul      Asia       41128771.0       38972230.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 0       33753499.0       28189672.0       19542982.0       10694796.0
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 0       12486631.0       10752971.0    652230.0            63.0587
#
#    Growth Rate  World Population Percentage
# 0       1.0257                         0.52

# %%
df.set_index('Country', inplace=True)
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
#                    2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan             38972230.0       33753499.0       28189672.0
# Albania                  2866849.0        2882481.0        2913399.0
# Algeria                 43451666.0       39543154.0       35856344.0
# American Samoa             46189.0          51368.0          54849.0
# Andorra                    77700.0          71746.0          71519.0
# ...                            ...              ...              ...
# Wallis and Futuna          11655.0          12182.0          13142.0
# Western Sahara            556048.0         491824.0         413296.0
# Yemen                   32284046.0       28516545.0       24743946.0
# Zambia                  18927715.0              NaN       13792086.0
# Zimbabwe                15669666.0       14154937.0       12839771.0
#
#                    2000 Population  1990 Population  1980 Population  \
# Country
# Afghanistan             19542982.0       10694796.0       12486631.0
# Albania                  3182021.0        3295066.0        2941651.0
# Algeria                 30774621.0       25518074.0       18739378.0
# American Samoa             58230.0          47818.0          32886.0
# Andorra                    66097.0          53569.0          35611.0
# ...                            ...              ...              ...
# Wallis and Futuna          14723.0          13454.0          11315.0
# Western Sahara            270375.0         178529.0         116775.0
# Yemen                   18628700.0       13375121.0        9204938.0
# Zambia                   9891136.0        7686401.0        5720438.0
# Zimbabwe                11834676.0       10113893.0        7049926.0
#
#                    1970 Population  Area (km²)  Density (per km²)  \
# Country
# Afghanistan             10752971.0    652230.0            63.0587
# Albania                  2324731.0     28748.0            98.8702
# Algeria                 13795915.0   2381741.0            18.8531
# American Samoa             27075.0       199.0           222.4774
# Andorra                    19860.0       468.0           170.5641
# ...                            ...         ...                ...
# Wallis and Futuna           9377.0       142.0            81.4930
# Western Sahara             76371.0    266000.0             2.1654
# Yemen                    6843607.0    527968.0            63.8232
# Zambia                   4281671.0    752612.0            26.5976
# Zimbabwe                 5202918.0    390757.0            41.7665
#
#                    Growth Rate  World Population Percentage
# Country
# Afghanistan             1.0257                         0.52
# Albania                 0.9957                         0.04
# Algeria                 1.0164                         0.56
# American Samoa          0.9831                         0.00
# Andorra                 1.0100                         0.00
# ...                        ...                          ...
# Wallis and Futuna       0.9953                         0.00
# Western Sahara          1.0184                         0.01
# Yemen                   1.0217                         0.42
# Zambia                  1.0280                         0.25
# Zimbabwe                1.0204                         0.20
#
# [234 rows x 16 columns]

# %%
df.sort_index(ascending=False)
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# ...                 ...  ...               ...       ...              ...
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
#
#                    2020 Population  2015 Population  2010 Population  \
# Country
# Zimbabwe                15669666.0       14154937.0       12839771.0
# Zambia                  18927715.0              NaN       13792086.0
# Yemen                   32284046.0       28516545.0       24743946.0
# Western Sahara            556048.0         491824.0         413296.0
# Wallis and Futuna          11655.0          12182.0          13142.0
# ...                            ...              ...              ...
# Andorra                    77700.0          71746.0          71519.0
# American Samoa             46189.0          51368.0          54849.0
# Algeria                 43451666.0       39543154.0       35856344.0
# Albania                  2866849.0        2882481.0        2913399.0
# Afghanistan             38972230.0       33753499.0       28189672.0
#
#                    2000 Population  1990 Population  1980 Population  \
# Country
# Zimbabwe                11834676.0       10113893.0        7049926.0
# Zambia                   9891136.0        7686401.0        5720438.0
# Yemen                   18628700.0       13375121.0        9204938.0
# Western Sahara            270375.0         178529.0         116775.0
# Wallis and Futuna          14723.0          13454.0          11315.0
# ...                            ...              ...              ...
# Andorra                    66097.0          53569.0          35611.0
# American Samoa             58230.0          47818.0          32886.0
# Algeria                 30774621.0       25518074.0       18739378.0
# Albania                  3182021.0        3295066.0        2941651.0
# Afghanistan             19542982.0       10694796.0       12486631.0
#
#                    1970 Population  Area (km²)  Density (per km²)  \
# Country
# Zimbabwe                 5202918.0    390757.0            41.7665
# Zambia                   4281671.0    752612.0            26.5976
# Yemen                    6843607.0    527968.0            63.8232
# Western Sahara             76371.0    266000.0             2.1654
# Wallis and Futuna           9377.0       142.0            81.4930
# ...                            ...         ...                ...
# Andorra                    19860.0       468.0           170.5641
# American Samoa             27075.0       199.0           222.4774
# Algeria                 13795915.0   2381741.0            18.8531
# Albania                  2324731.0     28748.0            98.8702
# Afghanistan             10752971.0    652230.0            63.0587
#
#                    Growth Rate  World Population Percentage
# Country
# Zimbabwe                1.0204                         0.20
# Zambia                  1.0280                         0.25
# Yemen                   1.0217                         0.42
# Western Sahara          1.0184                         0.01
# Wallis and Futuna       0.9953                         0.00
# ...                        ...                          ...
# Andorra                 1.0100                         0.00
# American Samoa          0.9831                         0.00
# Algeria                 1.0164                         0.56
# Albania                 0.9957                         0.04
# Afghanistan             1.0257                         0.52
#
# [234 rows x 16 columns]

# %%
df.iloc[[0]]
# Out:
#              Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Country
# Afghanistan    36  AFG   Kabul      Asia       41128771.0       38972230.0
#
#              2015 Population  2010 Population  2000 Population  \
# Country
# Afghanistan       33753499.0       28189672.0       19542982.0
#
#              1990 Population  1980 Population  1970 Population  Area (km²)  \
# Country
# Afghanistan       10694796.0       12486631.0       10752971.0    652230.0
#
#              Density (per km²)  Growth Rate  World Population Percentage
# Country
# Afghanistan            63.0587       1.0257                         0.52

# %% [markdown]
# ##### This shows iloc uses the initial index set when the data is loaded into the df
